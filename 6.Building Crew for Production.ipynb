# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 224 packages in 1.50s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# huggingface-hub ------------------------------     0 B/436.95 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# pydantic   ------------------------------     0 B/424.73 KiB
# huggingface-hub ------------------------------     0 B/436.95 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# watchfiles ------------------------------     0 B/415.51 KiB
# pydantic   ------------------------------     0 B/424.73 KiB
# huggingface-hub ------------------------------     0 B/436.95 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# prompt-toolkit ------------------------------     0 B/377.53 KiB
# watchfiles ------------------------------     0 B/415.51 KiB
# pydantic   ------------------------------     0 B/424.73 KiB
# huggingface-hub ------------------------------     0 B/436.95 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# trio       ------------------------------     0 B/470.44 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# ipython    ------------------------------     0 B/800.25 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# pydantic-core ------------------------------     0 B/1.96 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
# tzdata     ------------------------------ 14.88 KiB/338.46 KiB
# rpds-py    ------------------------------ 62.91 KiB/346.50 KiB
# prompt-toolkit ------------------------------ 30.87 KiB/377.53 KiB
# openai     ------------------------------ 30.92 KiB/377.88 KiB
# langchain-core ------------------------------ 14.91 KiB/398.18 KiB
# watchfiles ------------------------------ 62.88 KiB/415.51 KiB
# pydantic   ------------------------------ 30.88 KiB/424.73 KiB
# huggingface-hub ------------------------------ 41.35 KiB/436.95 KiB
# httptools  ------------------------------ 64.08 KiB/449.01 KiB
# crewai-tools ------------------------------ 16.00 KiB/452.58 KiB
# cffi       ------------------------------ 62.88 KiB/456.29 KiB
# trio       ------------------------------ 46.92 KiB/470.44 KiB
# pytz       ------------------------------ 14.88 KiB/496.10 KiB
# chromadb   ------------------------------ 30.88 KiB/513.14 KiB
# mpmath     ------------------------------ 62.84 KiB/523.63 KiB
# greenlet   ------------------------------ 30.91 KiB/588.29 KiB
# pyvis      ------------------------------ 30.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 16.00 KiB/774.23 KiB
# ipython    ------------------------------ 62.88 KiB/800.25 KiB
# langchain  ------------------------------ 14.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/218)
84 KiB/738.32 KiB
# pyyaml     ------------------------------ 541.06 KiB/745.07 KiB
# regex      ------------------------------ 494.02 KiB/774.23 KiB
# ipython    ------------------------------ 415.38 KiB/800.25 KiB
# langchain  ------------------------------ 62.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# jiter      ------------------------------ 16.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 16.83 KiB/333.85 KiB
# pytest     ------------------------------ 77.35 KiB/334.32 KiB
# yarl       ------------------------------ 120.62 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 204.93 KiB/377.53 KiB
# openai     ------------------------------ 142.92 KiB/377.88 KiB
# langchain-core ------------------------------ 190.80 KiB/398.18 KiB
# huggingface-hub ------------------------------ 380.86 KiB/436.95 KiB
# crewai-tools ------------------------------ 399.67 KiB/452.58 KiB
# trio       ------------------------------ 380.96 KiB/470.44 KiB
# pytz       ------------------------------ 123.58 KiB/496.10 KiB
# chromadb   ------------------------------ 384.87 KiB/513.14 KiB
# mpmath     ------------------------------ 508.47 KiB/523.63 KiB
# greenlet   ------------------------------ 508.49 KiB/588.29 KiB
# pyvis      ------------------------------ 501.80 KiB/738.32 KiB
# pyyaml     ------------------------------ 589.06 KiB/745.07 KiB
# regex      ------------------------------ 528.65 KiB/774.23 KiB
# ipython    ------------------------------ 431.38 KiB/800.25 KiB
# langchain  ------------------------------ 62.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# langsmith  ------------------------------ 32.00 KiB/289.94 KiB
# jiter      ------------------------------ 64.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 80.00 KiB/333.85 KiB
# pytest     ------------------------------ 141.35 KiB/334.32 KiB
# yarl       ------------------------------ 191.39 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 284.93 KiB/377.53 KiB
# openai     ------------------------------ 174.92 KiB/377.88 KiB
# langchain-core ------------------------------ 270.91 KiB/398.18 KiB
# huggingface-hub ------------------------------ 412.86 KiB/436.95 KiB
# crewai-tools ------------------------------ 431.67 KiB/452.58 KiB
# trio       ------------------------------ 412.34 KiB/470.44 KiB
# pytz       ------------------------------ 123.58 KiB/496.10 KiB
# chromadb   ------------------------------ 396.54 KiB/513.14 KiB
# greenlet   ------------------------------ 556.49 KiB/588.29 KiB
# pyvis      ------------------------------ 558.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 653.06 KiB/745.07 KiB
# regex      ------------------------------ 585.44 KiB/774.23 KiB
# ipython    ------------------------------ 463.38 KiB/800.25 KiB
# langchain  ------------------------------ 78.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# langsmith  ------------------------------ 32.00 KiB/289.94 KiB
# jiter      ------------------------------ 64.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 96.00 KiB/333.85 KiB
# pytest     ------------------------------ 141.35 KiB/334.32 KiB
# yarl       ------------------------------ 191.39 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 284.93 KiB/377.53 KiB
# openai     ------------------------------ 174.92 KiB/377.88 KiB
# langchain-core ------------------------------ 270.91 KiB/398.18 KiB
# huggingface-hub ------------------------------ 412.86 KiB/436.95 KiB
# crewai-tools ------------------------------ 431.67 KiB/452.58 KiB
# trio       ------------------------------ 412.34 KiB/470.44 KiB
# pytz       ------------------------------ 123.58 KiB/496.10 KiB
# chromadb   ------------------------------ 412.54 KiB/513.14 KiB
# greenlet   ------------------------------ 556.49 KiB/588.29 KiB
# pyvis      ------------------------------ 558.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 653.06 KiB/745.07 KiB
# regex      ------------------------------ 585.44 KiB/774.23 KiB
# ipython    ------------------------------ 479.38 KiB/800.25 KiB
# langchain  ------------------------------ 78.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# protobuf   ------------------------------ 10.71 KiB/287.73 KiB
# langsmith  ------------------------------ 80.00 KiB/289.94 KiB
# jiter      ------------------------------ 112.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 143.89 KiB/333.85 KiB
# pytest     ------------------------------ 177.59 KiB/334.32 KiB
# yarl       ------------------------------ 223.39 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 305.36 KiB/377.53 KiB
# openai     ------------------------------ 190.92 KiB/377.88 KiB
# langchain-core ------------------------------ 305.77 KiB/398.18 KiB
# crewai-tools ------------------------------ 431.67 KiB/452.58 KiB
# trio       ------------------------------ 444.34 KiB/470.44 KiB
# pytz       ------------------------------ 139.58 KiB/496.10 KiB
# chromadb   ------------------------------ 412.54 KiB/513.14 KiB
# greenlet   ------------------------------ 568.01 KiB/588.29 KiB
# pyvis      ------------------------------ 590.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 685.06 KiB/745.07 KiB
# regex      ------------------------------ 622.02 KiB/774.23 KiB
# ipython    ------------------------------ 479.38 KiB/800.25 KiB
# langchain  ------------------------------ 94.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# pypdf      ------------------------------ 14.92 KiB/287.57 KiB
# protobuf   ------------------------------ 42.71 KiB/287.73 KiB
# langsmith  ------------------------------ 112.00 KiB/289.94 KiB
# jiter      ------------------------------ 144.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 175.79 KiB/333.85 KiB
# pytest     ------------------------------ 205.35 KiB/334.32 KiB
# yarl       ------------------------------ 271.39 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 332.93 KiB/377.53 KiB
# openai     ------------------------------ 206.92 KiB/377.88 KiB
# langchain-core ------------------------------ 334.91 KiB/398.18 KiB
# trio       ------------------------------ 460.34 KiB/470.44 KiB
# pytz       ------------------------------ 139.58 KiB/496.10 KiB
# chromadb   ------------------------------ 428.09 KiB/513.14 KiB
# greenlet   ------------------------------ 568.01 KiB/588.29 KiB
# pyvis      ------------------------------ 622.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 733.06 KiB/745.07 KiB
# regex      ------------------------------ 653.92 KiB/774.23 KiB
# ipython    ------------------------------ 559.38 KiB/800.25 KiB
# langchain  ------------------------------ 94.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# pypdf      ------------------------------ 14.92 KiB/287.57 KiB
# protobuf   ------------------------------ 58.71 KiB/287.73 KiB
# langsmith  ------------------------------ 128.00 KiB/289.94 KiB
# jiter      ------------------------------ 160.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 191.79 KiB/333.85 KiB
# pytest     ------------------------------ 220.94 KiB/334.32 KiB
# yarl       ------------------------------ 271.39 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 332.93 KiB/377.53 KiB
# openai     ------------------------------ 206.92 KiB/377.88 KiB
# langchain-core ------------------------------ 334.91 KiB/398.18 KiB
# pytz       ------------------------------ 139.58 KiB/496.10 KiB
# chromadb   ------------------------------ 428.09 KiB/513.14 KiB
# greenlet   ------------------------------ 584.01 KiB/588.29 KiB
# pyvis      ------------------------------ 638.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 741.10 KiB/745.07 KiB
# regex      ------------------------------ 669.92 KiB/774.23 KiB
# ipython    ------------------------------ 567.26 KiB/800.25 KiB
# langchain  ------------------------------ 94.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 672.00 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/218)
# pypdf      ------------------------------ 29.78 KiB/287.57 KiB
# protobuf   ------------------------------ 58.71 KiB/287.73 KiB
# langsmith  ------------------------------ 128.00 KiB/289.94 KiB
# jiter      ------------------------------ 160.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 191.79 KiB/333.85 KiB
# pytest     ------------------------------ 220.94 KiB/334.32 KiB
# yarl       ------------------------------ 287.29 KiB/334.75 KiB
# tzdata     ------------------------------ 92.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 344.71 KiB/377.53 KiB
# openai     ------------------------------ 206.92 KiB/377.88 KiB
# langchain-core ------------------------------ 334.91 KiB/398.18 KiB
# pytz       ------------------------------ 139.58 KiB/496.10 KiB
# chromadb   ------------------------------ 428.09 KiB/513.14 KiB
# greenlet   ------------------------------ 584.01 KiB/588.29 KiB
# pyvis      ------------------------------ 638.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 741.10 KiB/745.07 KiB
# regex      ------------------------------ 669.92 KiB/774.23 KiB
# ipython    ------------------------------ 567.26 KiB/800.25 KiB
# langchain  ------------------------------ 110.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 688.00 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# bcrypt     ------------------------------     0 B/267.39 KiB
# frozenlist ------------------------------     0 B/268.43 KiB
# pypdf      ------------------------------ 29.78 KiB/287.57 KiB
# protobuf   ------------------------------ 60.63 KiB/287.73 KiB
# langsmith  ------------------------------ 144.00 KiB/289.94 KiB
# jiter      ------------------------------ 176.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 208.00 KiB/333.85 KiB
# pytest     ------------------------------ 220.94 KiB/334.32 KiB
# yarl       ------------------------------ 303.29 KiB/334.75 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 360.71 KiB/377.53 KiB
# openai     ------------------------------ 206.92 KiB/377.88 KiB
# langchain-core ------------------------------ 334.91 KiB/398.18 KiB
# pytz       ------------------------------ 139.58 KiB/496.10 KiB
# chromadb   ------------------------------ 428.09 KiB/513.14 KiB
# greenlet   ------------------------------ 584.01 KiB/588.29 KiB
# pyvis      ------------------------------ 654.40 KiB/738.32 KiB
# regex      ------------------------------ 679.74 KiB/774.23 KiB
# ipython    ------------------------------ 583.26 KiB/800.25 KiB
# langchain  ------------------------------ 110.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# qdrant-client ------------------------------     0 B/260.15 KiB
# bcrypt     ------------------------------ 16.00 KiB/267.39 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# pypdf      ------------------------------ 61.78 KiB/287.57 KiB
# protobuf   ------------------------------ 90.90 KiB/287.73 KiB
# langsmith  ------------------------------ 176.00 KiB/289.94 KiB
# jiter      ------------------------------ 208.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 224.00 KiB/333.85 KiB
# pytest     ------------------------------ 252.94 KiB/334.32 KiB
# yarl       ------------------------------ 319.29 KiB/334.75 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 360.71 KiB/377.53 KiB
# openai     ------------------------------ 222.92 KiB/377.88 KiB
# langchain-core ------------------------------ 350.91 KiB/398.18 KiB
# pytz       ------------------------------ 155.58 KiB/496.10 KiB
# chromadb   ------------------------------ 444.09 KiB/513.14 KiB
# pyvis      ------------------------------ 670.84 KiB/738.32 KiB
# regex      ------------------------------ 687.97 KiB/774.23 KiB
# ipython    ------------------------------ 591.38 KiB/800.25 KiB
# langchain  ------------------------------ 110.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# qdrant-client ------------------------------     0 B/260.15 KiB
# bcrypt     ------------------------------ 16.00 KiB/267.39 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# pypdf      ------------------------------ 77.78 KiB/287.57 KiB
# protobuf   ------------------------------ 90.90 KiB/287.73 KiB
# langsmith  ------------------------------ 191.78 KiB/289.94 KiB
# jiter      ------------------------------ 224.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 240.00 KiB/333.85 KiB
# pytest     ------------------------------ 268.94 KiB/334.32 KiB
# yarl       ------------------------------ 319.29 KiB/334.75 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# openai     ------------------------------ 222.92 KiB/377.88 KiB
# langchain-core ------------------------------ 350.91 KiB/398.18 KiB
# pytz       ------------------------------ 155.58 KiB/496.10 KiB
# chromadb   ------------------------------ 460.09 KiB/513.14 KiB
# pyvis      ------------------------------ 686.84 KiB/738.32 KiB
# regex      ------------------------------ 703.97 KiB/774.23 KiB
# ipython    ------------------------------ 607.16 KiB/800.25 KiB
# langchain  ------------------------------ 126.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 736.00 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# qdrant-client ------------------------------ 14.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 36.18 KiB/267.39 KiB
# frozenlist ------------------------------ 48.00 KiB/268.43 KiB
# pypdf      ------------------------------ 77.78 KiB/287.57 KiB
# protobuf   ------------------------------ 106.90 KiB/287.73 KiB
# langsmith  ------------------------------ 191.78 KiB/289.94 KiB
# jiter      ------------------------------ 224.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 240.00 KiB/333.85 KiB
# pytest     ------------------------------ 269.35 KiB/334.32 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# openai     ------------------------------ 222.92 KiB/377.88 KiB
# langchain-core ------------------------------ 366.91 KiB/398.18 KiB
# pytz       ------------------------------ 155.58 KiB/496.10 KiB
# chromadb   ------------------------------ 460.09 KiB/513.14 KiB
# pyvis      ------------------------------ 686.84 KiB/738.32 KiB
# regex      ------------------------------ 703.97 KiB/774.23 KiB
# ipython    ------------------------------ 623.38 KiB/800.25 KiB
# langchain  ------------------------------ 126.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 752.00 KiB/1.03 MiB
# pygments   ------------------------------ 670.32 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# google-cloud-bigquery ------------------------------     0 B/233.52 KiB
# rich       ------------------------------ 16.00 KiB/236.48 KiB
# cohere     ------------------------------    13 B/243.85 KiB
# qdrant-client ------------------------------ 46.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 60.97 KiB/267.39 KiB
# frozenlist ------------------------------ 76.95 KiB/268.43 KiB
# pypdf      ------------------------------ 94.92 KiB/287.57 KiB
# protobuf   ------------------------------ 124.63 KiB/287.73 KiB
# langsmith  ------------------------------ 208.00 KiB/289.94 KiB
# jiter      ------------------------------ 256.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 269.01 KiB/333.85 KiB
# pytest     ------------------------------ 301.35 KiB/334.32 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# openai     ------------------------------ 222.92 KiB/377.88 KiB
# langchain-core ------------------------------ 398.18 KiB/398.18 KiB
# pytz       ------------------------------ 155.58 KiB/496.10 KiB
# chromadb   ------------------------------ 476.54 KiB/513.14 KiB
# pyvis      ------------------------------ 718.84 KiB/738.32 KiB
# regex      ------------------------------ 734.02 KiB/774.23 KiB
# ipython    ------------------------------ 639.38 KiB/800.25 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# google-cloud-bigquery ------------------------------ 16.00 KiB/233.52 KiB
# rich       ------------------------------ 16.00 KiB/236.48 KiB
# cohere     ------------------------------ 14.92 KiB/243.85 KiB
# qdrant-client ------------------------------ 46.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 60.97 KiB/267.39 KiB
# frozenlist ------------------------------ 76.95 KiB/268.43 KiB
# pypdf      ------------------------------ 110.92 KiB/287.57 KiB
# protobuf   ------------------------------ 124.63 KiB/287.73 KiB
# langsmith  ------------------------------ 224.00 KiB/289.94 KiB
# jiter      ------------------------------ 272.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 285.01 KiB/333.85 KiB
# pytest     ------------------------------ 301.35 KiB/334.32 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# openai     ------------------------------ 222.92 KiB/377.88 KiB
# pytz       ------------------------------ 155.58 KiB/496.10 KiB
# chromadb   ------------------------------ 476.54 KiB/513.14 KiB
# pyvis      ------------------------------ 719.71 KiB/738.32 KiB
# regex      ------------------------------ 749.92 KiB/774.23 KiB
# ipython    ------------------------------ 639.38 KiB/800.25 KiB
# langchain  ------------------------------ 126.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# propcache  ------------------------------ 16.00 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 37.98 KiB/233.52 KiB
# rich       ------------------------------ 48.00 KiB/236.48 KiB
# cohere     ------------------------------ 46.92 KiB/243.85 KiB
# qdrant-client ------------------------------ 78.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 76.91 KiB/267.39 KiB
# frozenlist ------------------------------ 108.95 KiB/268.43 KiB
# pypdf      ------------------------------ 142.81 KiB/287.57 KiB
# protobuf   ------------------------------ 156.63 KiB/287.73 KiB
# langsmith  ------------------------------ 256.00 KiB/289.94 KiB
# jiter      ------------------------------ 304.00 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 301.01 KiB/333.85 KiB
# pytest     ------------------------------ 333.35 KiB/334.32 KiB
# tzdata     ------------------------------ 108.67 KiB/338.46 KiB
# openai     ------------------------------ 238.92 KiB/377.88 KiB
# pytz       ------------------------------ 171.58 KiB/496.10 KiB
# chromadb   ------------------------------ 492.54 KiB/513.14 KiB
# pyvis      ------------------------------ 735.71 KiB/738.32 KiB
# ipython    ------------------------------ 655.38 KiB/800.25 KiB
# langchain  ------------------------------ 126.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# alembic    ------------------------------     0 B/227.75 KiB
# propcache  ------------------------------ 16.00 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 53.98 KiB/233.52 KiB
# rich       ------------------------------ 48.00 KiB/236.48 KiB
# cohere     ------------------------------ 46.92 KiB/243.85 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 108.80 KiB/267.39 KiB
# frozenlist ------------------------------ 124.95 KiB/268.43 KiB
# pypdf      ------------------------------ 142.92 KiB/287.57 KiB
# protobuf   ------------------------------ 172.63 KiB/287.73 KiB
# langsmith  ------------------------------ 272.00 KiB/289.94 KiB
# jiter      ------------------------------ 311.67 KiB/311.67 KiB
# google-cloud-resource-manager ------------------------------ 320.00 KiB/333.85 KiB
# pytest     ------------------------------ 333.35 KiB/334.32 KiB
# tzdata     ------------------------------ 124.67 KiB/338.46 KiB
# openai     ------------------------------ 238.92 KiB/377.88 KiB
# pytz       ------------------------------ 171.58 KiB/496.10 KiB
# chromadb   ------------------------------ 508.54 KiB/513.14 KiB
# ipython    ------------------------------ 671.38 KiB/800.25 KiB
# langchain  ------------------------------ 142.92 KiB/981.64 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# alembic    ------------------------------     0 B/227.75 KiB
# propcache  ------------------------------ 16.00 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 53.98 KiB/233.52 KiB
# rich       ------------------------------ 48.00 KiB/236.48 KiB
# cohere     ------------------------------ 46.92 KiB/243.85 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 108.80 KiB/267.39 KiB
# frozenlist ------------------------------ 124.95 KiB/268.43 KiB
# pypdf      ------------------------------ 142.92 KiB/287.57 KiB
# protobuf   ------------------------------ 172.63 KiB/287.73 KiB
# langsmith  ------------------------------ 272.00 KiB/289.94 KiB
# google-cloud-resource-manager ------------------------------ 320.00 KiB/333.85 KiB
# pytest     ------------------------------ 333.35 KiB/334.32 KiB
# tzdata     ------------------------------ 124.67 KiB/338.46 KiB
# openai     ------------------------------ 238.92 KiB/377.88 KiB
# pytz       ------------------------------ 171.58 KiB/496.10 KiB
# chromadb   ------------------------------ 508.54 KiB/513.14 KiB
# ipython    ------------------------------ 671.38 KiB/800.25 KiB
# langchain  ------------------------------ 142.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 848.00 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# alembic    ------------------------------     0 B/227.75 KiB
# propcache  ------------------------------ 16.00 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 64.00 KiB/233.52 KiB
# rich       ------------------------------ 48.00 KiB/236.48 KiB
# cohere     ------------------------------ 46.92 KiB/243.85 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 108.80 KiB/267.39 KiB
# frozenlist ------------------------------ 140.95 KiB/268.43 KiB
# pypdf      ------------------------------ 158.92 KiB/287.57 KiB
# protobuf   ------------------------------ 188.63 KiB/287.73 KiB
# langsmith  ------------------------------ 288.00 KiB/289.94 KiB
# google-cloud-resource-manager ------------------------------ 333.85 KiB/333.85 KiB
# pytest     ------------------------------ 333.35 KiB/334.32 KiB
# tzdata     ------------------------------ 124.67 KiB/338.46 KiB
# openai     ------------------------------ 238.92 KiB/377.88 KiB
# pytz       ------------------------------ 171.58 KiB/496.10 KiB
# ipython    ------------------------------ 671.38 KiB/800.25 KiB
# langchain  ------------------------------ 142.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 848.00 KiB/1.03 MiB
# pygments   ------------------------------ 862.32 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# alembic    ------------------------------     0 B/227.75 KiB
# propcache  ------------------------------ 16.00 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 64.00 KiB/233.52 KiB
# rich       ------------------------------ 60.88 KiB/236.48 KiB
# cohere     ------------------------------ 46.92 KiB/243.85 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.15 KiB
# bcrypt     ------------------------------ 108.80 KiB/267.39 KiB
# frozenlist ------------------------------ 140.95 KiB/268.43 KiB
# pypdf      ------------------------------ 158.92 KiB/287.57 KiB
# protobuf   ------------------------------ 188.63 KiB/287.73 KiB
# langsmith  ------------------------------ 288.00 KiB/289.94 KiB
# google-cloud-resource-manager ------------------------------ 333.85 KiB/333.85 KiB
# tzdata     ------------------------------ 124.67 KiB/338.46 KiB
# openai     ------------------------------ 238.92 KiB/377.88 KiB
# pytz       ------------------------------ 171.58 KiB/496.10 KiB
# ipython    ------------------------------ 671.38 KiB/800.25 KiB
# langchain  ------------------------------ 142.92 KiB/981.64 KiB
# tiktoken   ------------------------------ 848.00 KiB/1.03 MiB
# pygments   ------------------------------ 862.32 KiB/1.15 MiB
# aiohttp    ------------------------------ 799.99 KiB/1.23 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/218)
# ...
# uv         ------------------------------ 13.07 MiB/13.07 MiB
# numpy      ------------------------------ 6.55 MiB/17.41 MiB
# lancedb    ------------------------------ 14.92 MiB/25.75 MiB
# pylance    ------------------------------ 15.81 MiB/28.63 MiB
# ⠇ Preparing packages... (210/218) 14.41 MiB/38.02 MiB
# pandas     ------------------------------ 12.33 MiB/12.45 MiB
# numpy      ------------------------------ 6.55 MiB/17.41 MiB
# lancedb    ------------------------------ 15.38 MiB/25.75 MiB
# pylance    ------------------------------ 15.91 MiB/28.63 MiB
# ⠇ Preparing packages... (210/218) 14.87 MiB/38.02 MiB
# pandas     ------------------------------ 12.45 MiB/12.45 MiB
# numpy      ------------------------------ 6.57 MiB/17.41 MiB
# lancedb    ------------------------------ 16.87 MiB/25.75 MiB
# pylance    ------------------------------ 17.44 MiB/28.63 MiB
# ⠋ Preparing packages... (213/218) 16.37 MiB/38.02 MiB
# pandas     ------------------------------ 12.45 MiB/12.45 MiB
# numpy      ------------------------------ 6.58 MiB/17.41 MiB
# lancedb    ------------------------------ 18.84 MiB/25.75 MiB
# pylance    ------------------------------ 19.09 MiB/28.63 MiB
# ⠋ Preparing packages... (213/218) 18.07 MiB/38.02 MiB
# numpy      ------------------------------ 6.58 MiB/17.41 MiB
# pylance    ------------------------------ 26.87 MiB/28.63 MiB
# ⠧ Preparing packages... (215/218) 26.19 MiB/38.02 MiB
# numpy      ------------------------------ 14.38 MiB/17.41 MiB
# pylance    ------------------------------ 26.87 MiB/28.63 MiB
# ⠧ Preparing packages... (215/218) 26.19 MiB/38.02 MiB
# numpy      ------------------------------ 14.39 MiB/17.41 MiB
# pylance    ------------------------------ 26.87 MiB/28.63 MiB
# ⠧ Preparing packages... (215/218) 26.19 MiB/38.02 MiB
# numpy      ------------------------------ 15.09 MiB/17.41 MiB
# pylance    ------------------------------ 26.87 MiB/28.63 MiB
# ⠇ Preparing packages... (215/218) 26.19 MiB/38.02 MiB
# numpy      ------------------------------ 16.03 MiB/17.41 MiB
# pylance    ------------------------------ 27.16 MiB/28.63 MiB
# ⠇ Preparing packages... (215/218) 26.52 MiB/38.02 MiB
# numpy      ------------------------------ 16.23 MiB/17.41 MiB
# pylance    ------------------------------ 27.36 MiB/28.63 MiB
# ⠋ Preparing packages... (215/218) 26.57 MiB/38.02 MiB
# numpy      ------------------------------ 16.23 MiB/17.41 MiB
# pylance    ------------------------------ 27.36 MiB/28.63 MiB
# ⠋ Preparing packages... (215/218) 26.88 MiB/38.02 MiB
# numpy      ------------------------------ 16.24 MiB/17.41 MiB
# pylance    ------------------------------ 27.36 MiB/28.63 MiB
# ⠋ Preparing packages... (215/218) 26.88 MiB/38.02 MiB
# numpy      ------------------------------ 16.26 MiB/17.41 MiB
# pylance    ------------------------------ 27.36 MiB/28.63 MiB
# ⠋ Preparing packages... (215/218) 26.88 MiB/38.02 MiB
# numpy      ------------------------------ 16.52 MiB/17.41 MiB
# pylance    ------------------------------ 27.80 MiB/28.63 MiB
# ⠋ Preparing packages... (215/218) 26.97 MiB/38.02 MiB
# numpy      ------------------------------ 16.52 MiB/17.41 MiB
# pylance    ------------------------------ 27.80 MiB/28.63 MiB
# ⠙ Preparing packages... (215/218) 27.88 MiB/38.02 MiB
# numpy      ------------------------------ 16.52 MiB/17.41 MiB
# pylance    ------------------------------ 27.80 MiB/28.63 MiB
# ⠙ Preparing packages... (215/218) 29.99 MiB/38.02 MiB
# numpy      ------------------------------ 16.52 MiB/17.41 MiB
# pylance    ------------------------------ 27.88 MiB/28.63 MiB
# ⠙ Preparing packages... (215/218) 29.99 MiB/38.02 MiB
# numpy      ------------------------------ 17.23 MiB/17.41 MiB
# ⠙ Preparing packages... (215/218) 29.99 MiB/38.02 MiB
# numpy      ------------------------------ 17.36 MiB/17.41 MiB
# ⠙ Preparing packages... (215/218) 29.99 MiB/38.02 MiB
# ⠙ Preparing packages... (215/218) 29.99 MiB/38.02 MiB
# ⠙ Preparing packages... (215/218) 30.00 MiB/38.02 MiB
# ⠙ Preparing packages... (215/218) 31.88 MiB/38.02 MiB
# ⠹ Preparing packages... (217/218) 35.03 MiB/38.02 MiB
# Prepared 218 packages in 7.48s
# Installed 218 packages in 153ms
#  + aiohappyeyeballs==2.4.3
#  + aiohttp==3.10.10
#  + aiosignal==1.3.1
#  + alembic==1.13.3
#  + annotated-types==0.7.0
#  + anyio==4.6.2.post1
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==2.4.1
#  + attrs==24.2.0
#  + auth0-python==4.7.2
#  + backoff==2.2.1
#  + bcrypt==4.2.0
#  + beautifulsoup4==4.12.3
#  + build==1.2.2.post1
#  + cachetools==5.5.0
#  + certifi==2024.8.30
#  + cffi==1.17.1
#  + charset-normalizer==3.4.0
#  + chroma-hnswlib==0.7.3
#  + chromadb==0.4.24
#  + click==8.1.7
#  + cohere==5.11.1
#  + coloredlogs==15.0.1
#  + crewai==0.76.2
#  + crewai-tools==0.13.2
#  + cryptography==43.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.14
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + docx2txt==0.8
#  + durationpy==0.9
#  + embedchain==0.1.123
#  + executing==2.1.0
#  + fastapi==0.115.3
#  + fastavro==1.9.7
#  + filelock==3.16.1
#  + flatbuffers==24.3.25
#  + frozenlist==1.5.0
#  + fsspec==2024.10.0
#  + google-api-core==2.21.0
#  + google-auth==2.35.0
#  + google-cloud-aiplatform==1.70.0
#  + google-cloud-bigquery==3.26.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.12.5
#  + google-cloud-storage==2.18.2
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.65.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.13.1
#  + grpcio==1.67.0
#  + grpcio-status==1.62.3
#  + grpcio-tools==1.62.3
#  + h11==0.14.0
#  + h2==4.1.0
#  + hpack==4.0.0
#  + httpcore==1.0.6
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.26.1
#  + humanfriendly==10.0
#  + hyperframe==6.0.1
#  + idna==3.10
#  + importlib-metadata==8.4.0
#  + importlib-resources==6.4.5
#  + iniconfig==2.0.0
#  + instructor==1.6.3
#  + ipython==8.28.0
#  + jedi==0.19.1
#  + jinja2==3.1.4
#  + jiter==0.5.0
#  + json-repair==0.30.0
#  + jsonpatch==1.33
#  + jsonpickle==3.3.0
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==31.0.0
#  + lancedb==0.14.0
#  + langchain==0.3.4
#  + langchain-cohere==0.3.1
#  + langchain-community==0.3.3
#  + langchain-core==0.3.12
#  + langchain-experimental==0.3.2
#  + langchain-openai==0.2.3
#  + langchain-text-splitters==0.3.0
#  + langsmith==0.1.137
#  + litellm==1.50.2
#  + mako==1.3.6
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.23.0
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.23
#  + mmh3==5.0.1
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.19.2
#  + openai==1.52.2
#  + opentelemetry-api==1.27.0
#  + opentelemetry-exporter-otlp-proto-common==1.27.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.27.0
#  + opentelemetry-exporter-otlp-proto-http==1.27.0
#  + opentelemetry-instrumentation==0.48b0
#  + opentelemetry-instrumentation-asgi==0.48b0
#  + opentelemetry-instrumentation-fastapi==0.48b0
#  + opentelemetry-proto==1.27.0
#  + opentelemetry-sdk==1.27.0
#  + opentelemetry-semantic-conventions==0.48b0
#  + opentelemetry-util-http==0.48b0
#  + orjson==3.10.10
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==24.1
#  + pandas==2.2.3
#  + parameterized==0.9.0
#  + parso==0.8.4
#  + pexpect==4.9.0
#  + pluggy==1.5.0
#  + portalocker==2.10.1
#  + posthog==3.7.0
#  + prompt-toolkit==3.0.48
#  + propcache==0.2.0
#  + proto-plus==1.25.0
#  + protobuf==4.25.5
#  + ptyprocess==0.7.0
#  + pulsar-client==3.5.0
#  + pure-eval==0.2.3
#  + py==1.11.0
#  + pyarrow==17.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.9.2
#  + pydantic-core==2.23.4
#  + pydantic-settings==2.6.0
#  + pygments==2.18.0
#  + pyjwt==2.9.0
#  + pylance==0.18.2
#  + pypdf==5.0.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.386
#  + pysbd==0.3.4
#  + pysocks==1.7.1
#  + pytest==8.3.3
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.12.0
#  + referencing==0.35.1
#  + regex==2024.9.11
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + retry==0.9.2
#  + rich==13.9.3
#  + rpds-py==0.20.0
#  + rsa==4.9
#  + schema==0.7.7
#  + selenium==4.25.0
#  + setuptools==75.2.0
#  + shapely==2.0.6
#  + shellingham==1.5.4
#  + six==1.16.0
#  + sniffio==1.3.1
#  + sortedcontainers==2.4.0
#  + soupsieve==2.6
#  + sqlalchemy==2.0.36
#  + stack-data==0.6.3
#  + starlette==0.41.0
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.1
#  + tomli-w==1.1.0
#  + tqdm==4.66.5
#  + traitlets==5.14.3
#  + trio==0.27.0
#  + trio-websocket==0.11.1
#  + typer==0.12.5
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2024.2
#  + urllib3==2.2.3
#  + uv==0.4.26
#  + uvicorn==0.32.0
#  + uvloop==0.21.0
#  + watchfiles==0.24.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==13.1
#  + wrapt==1.16.0
#  + wsproto==1.2.0
#  + yarl==1.16.0
#  + zipp==3.20.2

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Advancements in Multimodal Capabilities**: AI LLMs are increasingly being integrated with multimodal capabilities, allowing them to process and generate text, images, and even video content, making them more versatile in applications like virtual assistants and creative content generation.
#
# 2. **Fine-tuning Techniques**: New strategies for fine-tuning LLMs have emerged, such as low-shot and few-shot learning, allowing models to adapt to specific tasks with minimal additional data, significantly reducing the resources required for training specialized models.
#
# 3. **Eco-friendly AI**: Researchers are focusing on developing energy-efficient models due to growing concerns about the environmental impact of training large AI systems. Techniques such as model distillation and pruning are being implemented to create smaller, more sustainable models.
#
# 4. **Ethical AI and Bias Mitigation**: The AI community is prioritizing ethical considerations by developing tools and frameworks to detect and mitigate biases in LLMs, aiming to ensure fair and equitable AI solutions across diverse applications.
#
# 5. **Real-time Language Processing**: LLMs can now deliver real-time responses in conversational AI systems, making them suitable for applications such as customer support and interactive training modules, vastly improving user experience.
#
# 6. **Integration with Augmented Reality (AR) and Virtual Reality (VR)**: AI LLMs are being utilized to create dynamic and responsive environments in AR and VR applications, offering users tailored narratives and interactions in immersive digital landscapes.
#
# 7. **Enhanced Memory and Context Capabilities**: Recent innovations have improved LLMs' abilities to remember contextual information over longer interactions, allowing for more coherent and contextually aware conversations with users.
#
# 8. **Open Source Collaborations**: There is a surge in open-source projects focused on LLM development, encouraging community-driven enhancements and fostering collaboration among researchers and developers to push the boundaries of AI language technologies.
#
# 9. **Human-AI Collaboration**: New tools are being designed to facilitate productive collaboration between humans and AI systems, enabling users to leverage LLMs for brainstorming, content creation, and data analysis more effectively.
#
# 10. **Regulatory Frameworks**: Governments and regulatory bodies are establishing guidelines and frameworks for the use of AI LLMs, focusing on transparency, accountability, and data privacy to ensure responsible deployment of these powerful tools in various sectors.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Detailed Report on AI LLMs Developments
#
# ## 1. Advancements in Multimodal Capabilities
# AI Language Models (LLMs) are evolving dramatically, incorporating multimodal capabilities that allow them to process and generate various forms of content beyond just text. These advancements enable LLMs to analyze images, videos, and audio, facilitating a more versatile interaction model that can cater to a wider array of applications. For instance, virtual assistants can now not only provide textual responses but can also generate visual aids for explanations or support users through video content. This has significant implications for fields such as education, where interactive multimedia resources enhance learning experiences and comprehension, and creative sectors, where artists can collaborate with AI to generate novel content effortlessly.
#
# ## 2. Fine-tuning Techniques
# The development of advanced fine-tuning techniques, including low-shot and few-shot learning, has transformed how LLMs are tailored for specific tasks. These techniques enable models to learn from just a handful of examples, drastically reducing the dependence on extensive datasets that often require considerable resources to compile and annotate. This evolution allows organizations to deploy specialized models efficiently, catering to niche domains without incurring high costs or lengthy training periods. Organizations can adapt AI systems to their specific needs quickly and effectively, leading to quicker implementation cycles and more tailored solutions.
#
# ## 3. Eco-friendly AI
# With the increasing awareness of the environmental implications of large-scale AI training, researchers are actively working towards creating energy-efficient models. Techniques like model distillation help in producing smaller models that replicate the performance of larger counterparts, while pruning techniques eliminate unnecessary parameters, resulting in lighter models. These innovations aim to reduce the computational costs associated with training and running AI systems. Such eco-friendly approaches are essential for ensuring sustainable AI development, particularly as industry adoption of AI technologies grows and the need for greener solutions becomes more pressing.
#
# ## 4. Ethical AI and Bias Mitigation
# The ethical considerations surrounding AI deployment have gained paramount importance, pushing the AI community to focus on developing strategies for bias detection and mitigation. Various frameworks and tools have been developed to analyze and address biases in LLM responses, promoting fairness and equity in AI outputs. This shift is crucial to prevent perpetuating stereotypes or ingraining harmful biases into AI systems, ensuring that diverse user perspectives are respected. Responsible AI practices foster trust and acceptance from users, making ethical considerations a critical focus for future AI advancements.
#
# ## 5. Real-time Language Processing
# One of the most significant advancements in LLMs is their ability to provide real-time responses in conversational AI systems. This capability greatly enhances user experience in applications such as customer support and interactive training modules by allowing for fluid, human-like interactions. The immediacy of responses improves efficiency and satisfaction, allowing organizations to offer timely assistance to users and providing a seamless learning environment. This advancement has revolutionized user interactions with AI and positioned LLMs as invaluable tools in various industry applications.
#
# ## 6. Integration with Augmented Reality (AR) and Virtual Reality (VR)
# The integration of AI LLMs with AR and VR technologies is creating dynamic and engaging user experiences in immersive environments. LLMs can generate tailored narratives and interactions based on user inputs, enhancing the immersion factor of virtual experiences. This capability is particularly valuable in gaming, simulations, and training programs, where personalized content can significantly improve user engagement and retention. As AR and VR technology continues to evolve, the collaboration with LLMs will facilitate richer, more interactive experiences that bridge the gap between the virtual and real worlds.
#
# ## 7. Enhanced Memory and Context Capabilities
# Recent innovations have significantly improved LLMs' memory and context retention capabilities, allowing models to remember and reference relevant information over longer interactions. This enhancement leads to more coherent dialogue patterns and contextually aware conversations, creating a more engaging and fulfilling user experience. Users can engage with AI systems more naturally, recalling previous discussions or experiences without repeating information. This capability is especially useful in applications requiring ongoing dialogue, such as therapy, customer relationship management, and education.
#
# ## 8. Open Source Collaborations
# The surge in open-source projects in the field of LLM development represents a significant trend towards community-driven innovation. Collaborative efforts allow researchers and developers to share insights, resources, and improvements, pushing the boundaries of AI language technologies. Such projects foster transparency, enabling users to scrutinize model development processes and implement necessary improvements. The democratization of AI knowledge not only accelerates advancements but also empowers smaller organizations with access to cutting-edge technology that might have been previously unattainable due to resource constraints.
#
# ## 9. Human-AI Collaboration
# New tools and platforms are being developed to enhance collaboration between humans and AI systems, promoting efficient teamwork in tasks such as brainstorming, content creation, and data analysis. These innovations are designed to streamline workflows and enhance productivity, encouraging users to leverage the capabilities of LLMs as powerful assistants rather than standalone entities. By integrating AI into human processes, organizations can benefit from rapid ideation and data processing, allowing for more strategic decision-making and innovative outcomes.
#
# ## 10. Regulatory Frameworks
# As AI technologies, particularly LLMs, become increasingly prominent in various sectors, regulatory bodies worldwide are establishing guidelines aimed at ensuring responsible and ethical deployment. These frameworks focus on transparency, accountability, and data privacy, addressing concerns about misuse or unintended consequences of AI algorithms. By creating structured guidelines, governments can support innovation while safeguarding the rights and interests of users. Clear regulations are essential for fostering public trust in AI technologies and ensuring that deployments align with ethical standards and societal norms.
#
# This comprehensive report outlines key advancements and considerations surrounding AI LLMs, offering insights into the future directions of this pivotal technology. Each section illustrates the integral role that LLMs play across various domains, emphasizing the importance of ethical use and sustainable practices as the field continues to evolve.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
